# %%
students = ["Mohan", "Vishwa", "Shivam", "Sakshi"]
print(students)
print(type(students)) # This will print the type list her ein the result
# Out:
# ['Mohan', 'Vishwa', 'Shivam', 'Sakshi']
# <class 'list'>

# %%
list2 = list(students)
print(list2) # Here with the help of this code it will get converted in the form of a code
# Out:
# ['Mohan', 'Vishwa', 'Shivam', 'Sakshi']

# %%
list3 = list("Vishwa")
print(list3) # Here as we can see that the letters are getting printed seperately
# Out:
# ['V', 'i', 's', 'h', 'w', 'a']

# %%
list4 = list((3,4,"Vishwa"))
print(list4)
# Out:
# [3, 4, 'Vishwa']

# %%
# No we move on to accessing the elements in the list 
l1 = [1,3,9,2,5,6,7]
print(l1[3]) # It will print the element with the number 3 indexing 
print(l1[-6]) # It will print the element with the number -6 indexing
# Out:
# 2
# 3

# %%
arr =[3,2,1,5,9]
arr.append(11)
print(arr) # Here we use the append function to add 11 in the array at the end
# Out:
# [3, 2, 1, 5, 9, 11]

# %%
arr = [3,2,1,5,9]
arr.insert(3,43)
print(arr) # Here it will add the element at the 3rd indexing
# Out:
# [3, 2, 1, 43, 5, 9]

# %%
l1 = [1,2]
l2 = ["Vishwa" , "Mohan"]
l1.extend(l2)
print(l1) 
# Here when we run the code, the array gets extended and more elements added
# Out:
# [1, 2, 'Vishwa', 'Mohan']

# %%
arr =[3,5,2,1,9]
arr.remove(1)
print(arr) # Here we remove the element 1 from the list by using the remove function
# Out:
# [3, 5, 2, 9]

# %%
arr = [3,5,2,1,9,1,8,1]
arr.remove(1)
print(arr) # It will remove the first ocuurence of 1 from the list
# Out:
# [3, 5, 2, 9, 1, 8, 1]

# %%
# pop function 
arr = [3,1,7,9,11,23,45]
print(arr.pop(2))
print(arr) # Here the pop function will replace the function with the number 3 indexing and print the array without the element
# Out:
# 7
# [3, 1, 9, 11, 23, 45]

# %%
student = ['a', 'b', 'c', 'd', 'e']
student[3] = 'f'
print(student) # Here f replaces d in the array 

student[1:4] = 'm', 'n'
print(student) # Here and n get printed in the array at the index
# Out:
# ['a', 'b', 'c', 'f', 'e']
# ['a', 'm', 'n', 'e']
