# %% [markdown]
# Q1.
# What is the purpose of file handling in Python, and why is it essential for organizations ?

# %% [markdown]
# Ans.
# The file handling in Python serves as the critical function for enabling the storage and retrival of the data from secondary storage devices such as Hard Drives and SSDs.  It allows the programs to interact with files on the system, enablin the tasks like reading data from files, writing data to the files and manipulating the file contents.
#
# For organizations, fil handling is essential as it facilitates the permanent storage of vital information, suuch as employee records, inventory data, sales figure and more ensuring that data can be reused and accessed as needed.

# %% [markdown]
# Q2.
# Explain the concept of a file in Python and its role in storing data permanently ?

# %% [markdown]
# Ans.
#
# Concept of a File in Python :
# In Python, a file is named as a location on a seconary storage devie where data is permanently stored for later access.  Files can be categorized into two main types : text files and binary files.
#
# Text files consist of the human readable characters  while binary files consist of the non human readable dataa such as images, audio or executable files.  Each file is stored as a sequence or bytes, with text files being encooded  using schemes like ASCII or UNICODE to represent characters.

# %% [markdown]
# Q3.
# Differentiate between text files and binary files in Python, providing examples of each ?

# %% [markdown]
# Ans.
# Text files contain the human readable characters and are typically encoded using ASCII, UNICODE or other encoding schemes.
# Examples include files with extensions like the .txt, .py or .csv .
#
# on the other hand, binary files store non human readable data such as images, or executables, represented as sequences of bytes.
# Text files can be opened and read using any text editor, while binary files require specific programs to access their contents.

# %% [markdown]
# Q4.
# How are text files stored internally, and how does a text editor interpret the contents of a text file ?

# %% [markdown]
# Ans.
# Internal storage of text files :
# Text files are stored internally as sequences of bytes with each characterr represented by its ASCII or UNICODE value.  While text editors,  display the text files as readable characters, internaly, they are stored as binary data.
#
# Each line of a text file is terminated by a special End of LIne (EOL) character, such as newline (\n) and contents are typically seperated by whitespace, commas or tabs.

# %% [markdown]
# Q5.
# Describe the process of opening and closing a text file in Python, including the syntax and optional
# arguments ?

# %% [markdown]
# Ans.
# In Python, files are opened using the open() function, which returns a file object representing the opened file.
# The opened file. The function takes two main arguments: the file name and the access mode. Access odel includes the 'r'for the reading, 'w'for writing, a for appending and combinations like r+ and w+ .
#
# Its important to cloe files after using the close() mehod to release the system resources and ensure data integrity.

# %% [markdown]
# Q6.
# What are the various file access modes available in Python's open() function, and how do they affect file
# handling ?

# %% [markdown]
# Ans.
# Python's open() function supports the varioous file models access, including the read only, write only, append, read/write, and binary modes. These modes determine how the filw will be handled such as the whether it can be read from, written to or both and whether it is opened in text or binary mode.

# %% [markdown]
# Q7. Explain the process of catching exceptions using the `try...except` block in Python. Illustrate with
# examples ?

# %% [markdown]
# Ans.
# The with clauuse in Python provides the a convenient way to open and manage the files.  It ensures that the file is automatically closed once the  block of code inside the with ststement completes even if an exception occurs.
#
# This simplifies the file handlinng code and helps avoid the resources leak.

# %% [markdown]
# Q8.
# Discuss the use of the `finally` clause in Python exception handling. When and why is it used? Provide
# examples to support your explanation ?

# %% [markdown]
# Ans.
# In Python,  data can be written to a text dile using methods like write(), for writing a single string, or writelines() for writng a sequence of srings.
#
# Strings are written to the file as bytes and it's important to handle newline characters appropriately to format the data correctly.

# %% [markdown]
# Q9.
# How can multiple exceptions be handled in Python using the `try...except` block? Provide examples
# demonstrating the handling of multiple exceptions ?

# %% [markdown]
# Ans.
# Writing the Numeric Data to a Text File :
# Numeric Data must be converted to strings using the functions like str() before writing to  a text file in Python.
# This ensures that the data is written as human readable text rather than binary representation of numbers.

# %% [markdown]
# Q10.
#
# What is the significance of the `else` clause in Python exception handling? How does it complement the
# `try...except` block? Provide examples to elucidate its usage ?

# %% [markdown]
# Ans.
# The write() method overwrites the contents of a file if it already exists, starting from the beginning, while the append() method adds
# new data to the end of existing file without erasing the previous content.
#
# Both methoods are used for writing the data to files, but their behaviour differs regarding existing file content.

# %% [markdown]
# Q11.
# What is operator overloading in Python, and how does it allow for customization of built-in operators ?

# %% [markdown]
# Ans.
# Methods for reading the dat from a text file :
# Python provides the severalmethods for reading the data from a text file including the read() for reading all the lines into a list.
#
# These methods allow the sequntial access to the contents of a file, enabling data retrieval for processing.

# %% [markdown]
# Q12.  Explain the significance of magic methods (or dunder methods) in Python operator overloading. Provide
# examples of commonly used magic methods for operator overloading ?

# %% [markdown]
# Ans.
# Usage of tell() and seek() methods are as follows :
# The tell() method returns the currennt position of the file object within the file measured in bytesfrom the beginning.
# Conversely the seek(), method is used to move the file object to a specified position within the file.
#
# It accepts the arguments for the offset and the reference point enabling random access to  the file contents.

# %% [markdown]
# Q13.
# Describe the process of implementing operator overloading in a custom Python class. Provide an
# example demonstrating the overloading of addition and subtraction operators ?

# %% [markdown]
# Ans.
#
# Creating a file and writing the Data :
# To create a text file in Python, the open() function is used with appropriate access mode such as w for write oode. If the file is already exists, its coontents may be overwritten or append based on the mode used.
#
# The file handle returnded by open() is then used to write data to the file using methods like write() or  writelines().

# %% [markdown]
# Q14.
# How do comparison operators and assignment operators contribute to operator overloading in Python?
# Provide examples illustrating their usage in custom class implementations ?

# %% [markdown]
# Ans.
# Best practices for the File handling :
# Best Practices for the file handling in Python include the closing of the files after use to release system resources, using error handling mechanisms like exception handling to manage potential errors during the file operations and leveraging contentmanagers like the
# "with" statement for automatic resource cleanupp.
#
# Additionally, its important to handle the file paths and permissions correctly to ensure data integrity and security.

# %% [markdown]
# Q15.  Discuss the advantages of operator overloading in Python programming. How does it improve code
# readability, expressiveness, and maintainability ?

# %% [markdown]
# Ans.
# In Python, both the packages and modules are the organizational units that are used to structure code and facilitate code resue but they solve different purposes and have distinct characterstics.
#
# Modules :
#
# Modules are single Python files containing the Python Code that can be executed or imported.
# They are used to organize the related functions, classes or variables into a single file making code organization and reuse easier.
#
# Modules can be imported intoother Python scripts or modules using the import statement.
# Suppose : We have a module named math_operations.py containing functions for performing the mathematical operations.
#
# Packages :
# Packages are directories or folders containing the multiple modules and an additional __init__.py  file.
#
# They are used to organize the related modules into a hierarchial structure allowing for better organization and mnagement for large codebases.
#
# Packages can have sub packages which are simply nested directories with their own __init__.py files.
#
# Packages can be imported ina similar way to modules using the import statement but they may require specifying the module or sub package name.
#
# Suppose we may have a package named math_library containing the multiple modules for various mathematical operations.
#
# math_library/
# __init__.py
# arithmetic.py
#
# geometry/
#  __init__.py
#  shapes.py
#  statistics.py
#
#  In this example, math_library, is the pacakge, arithmetic.py and statistics.py are modules directly within the package and the geometry is a sub package containing its own modules.
#
#  Difference :
#  Modules are individual python files containing code while packages are directories or folders containing the multiple modules along with an __init__.py file.
#
#  Modules are meant for organizing the code within a single file hile the packages are used for organizing and structuring the code across multiple files and directories.
#
#  Modules are imported using the import statement while the packages are imported similarly but may require specifying the module or sub package name.
#
#  Modules do not require an __init__.py file while packages must have one to be recognized as packages by Python.

# %%
# math_operations.py   
def add (x,y): 
    return x + y 

def subtract( x,y): 
    return x - y

def multiply (x,y): 
    return x*y

print(add(5,3))
print(subtract(6,7))
# Out:
# 8
# -1
