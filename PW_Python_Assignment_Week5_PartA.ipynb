# %% [markdown]
# Q1. What is Object Oriented Programming ? How is it different  from procedural programming ?

# %% [markdown]
# Ans. Object Oriented programming is a tpe of programming that mainly focuses on creating objects, which are mainly
#     instance of classes.
#
#     OOp is mainly based on the priciples which are :
#
# 1. Encapsulation : Binding the data and the methods that operate on that data within a single unit.
#
# 2. Abstraction : Focusing on essential features and hiding the unnecessary details
#
# 3. Inheritance : Creating new classes based on the existing ones, inheritng the properties and behaviors.
#
# 4. Polymorphism : Polymorphism basiclly allows the objects of different classes to be treated ass the objects of a
#                   common super class.
#
# Whereaas, the Procedural Programming is a programming paradigm that focuses on the breaking down a program in to a series
# of proocedures  or functions. Procedural Programming is more concerned with describing the steps that the program should take
# to achieve a particular result, rather than modeling real world objects and their interactins.

# %% [markdown]
# Q2. Define the term Class, Attribute and Object in the context of OOP in Python ?

# %% [markdown]
# Ans.
# Class : A Class is a blueprint or the template for creaating the objects . It defines the data and the methods that the
#         objects of the class will have.
#
# Attribute : An attribute is a variable that is associated with a class or an object. Attributes can be used to store data or define the
#            characterstics of an object.
#
# Object : An object is an instance of class. it is a real world entity that has its own state(attributs) and behavior(methods).

# %% [markdown]
# Q3. Explain the role of instances in Python classes. How are instances created and what purpose do they have ?

# %% [markdown]
# Ans.
# Instances : instances are the individual objects that are created from the class. Each instance has its own set of attributes and
#             can perform the methods defined in the class .
# Instances are created using the class name followed  by parenthesis.
# Example :    "my_object" = className()
#
# Instances serve as the purpose of allowing you to ceate and work with specific objects based on the class definition.

# %% [markdown]
# Q4. Describe the process of defning a class in python including the syntax and the components involved ?

# %%
# Definign a class in Python 

class className : 
    class_attr1 = value 
    class_attr2 = value 

    def __init__(self,param1, param2): # instance attributes 
        self.instance.attr1 = param1
        self.instance.attr2 = param2


     #  methods  
     def method1(self):
        pass 


    def method2 (self,arg):
        pass

# %% [markdown]
# The key components are :
# 1. className defines the anem of the class
# 2. __init__  It is the constructuor method used to initialize the objects'attributes
# 3. Instance attributes are defined using the self.attribute = name
# 4. Methods are defined using the attributes name by def method_name(self, _ )

# %% [markdown]
# Q5. How are functions defined  within a class in the python ? What is the significance of 'self'parameter ?

# %% [markdown]
# Ans.
# Defining functions within a class :
# Functions defined within a class are called methods. The first method is conventionally named 'self' and it represents
# the instance of the class, that the method is being called on.
#
# The self method is being called to allow method to access the instance's attributes.

# %% [markdown]
# Q6.  Explain how class functions can be caled from both outside and inside the class in Python, providing the examples in Python
#    for each scenario.

# %% [markdown]
# Ans.
# Calling class attributes :
#
# From outside the class attributes : "object_instance". method_name(arguments)
#
# From  inside the class : 'self.method_name(srguments)"

# %% [markdown]
# Q7.  Differentiate between theclass attributes and the instance attributes in Python, and provide examples in each.

# %% [markdown]
# Ans.
#
# Class Attributes vs instance Attributes :
# Class Attributes : Attributes are shared among all the instances of a class . They are defined at the class level.
#
# Instance Attributes :
# Attributes that are specific to each instance of class. They sre defined within the __init__ method or other instance methods.

# %% [markdown]
# Q8. Differentiate between the class method, instance method and static method in Python and provide examples for each.

# %% [markdown]
# Ans.
#
# Class Method, instance method and static method :
#
# Instance Method :  A method takes place the self parameter snd can access and modify the instance attributes.
#
# Class Methods :  A method that takes the 'cls' parameter and can access and modify the class attributes .
#                  They are defined using the @classmethod  decorator.
#
# Static Method  :  A method that does not take the 'self' or 'cls' parameter and does not have access to  instance or class attributes.
# They are defined using the @stationmethod  decorator.

# %% [markdown]
# Q9.  What is a coonstructor in Python ? How is it defined and what is its purpose ?

# %% [markdown]
# Ans.
# Constructors in Python classes :
#
# The __init__ method is the constructor in Python classes. It is called automatically when an object is created from the class.
#
# The constructor is used to initialize thr objects' attributes with the provided arguments.

# %% [markdown]
# Q10.  What are access specifiers in Python.  Explain with examples.

# %% [markdown]
# Ans.
# Access Specifiers in Python  :
#
# Access Specifiers in Python :
#  In Python, there are no explicit access specifiers like 'public', 'private' and practiced as in some other object
#     oriennted programming languages.   Python has a naming convention to indicate the intended access level of a class
#     member.
#
# Public :  Variables are methods that are accessible from anywhere , both inside and outside the class.
#
# They are named wwithout any special prefixes.

# %%
class myClass : 
    def __init__(self, value): 
        self.public.attr = value 
    def public_method(self):
        print("This is a public method")

# %% [markdown]
# Protected : Variables and managers that are intended  to be accesses only by the class and its sub cases.
#
#              They are named with a leading underscore (_).

# %%
class myClass : 
    def __init__(self,value): 
        self._protected_attr = value 
    def _protected_method(self): 
        print("This is a protected method")

# %% [markdown]
# Private Method : Variables and methods that are intended to be accessed only within the class.
#
#                 They are named within 2 leading underscore (__)

# %%
class MyClass : 
    def __init__(self, value):
        self.__private__attr = value
    def _private_method (self):
        print("This is a private method")

# %% [markdown]
# While Python does not  access control, the naming  convention is widely used to indicate the intended access level road.
#
# It is generally considered a good practice to follow it.

# %% [markdown]
# Q11.  What is encapsulation in python. Explain it with example.  How does it promote data hiding and abstraction
#      and why it is important in software design.

# %% [markdown]
# Ans.
#
# Encapsulation in Python :
# Encapsulation in Python is a fundamental concept in object oriented programming. that involves bundling data
# and the methods that operate on that data within a single unit.
# It provides data hiding and abstraction.
#
# Data Hiding :
# Encapsulation allows you to hide the internal implemantation details of an object from the outside world.
# By using the private attributes and providing controlle access through methods, you can ensure that the data is
# accessed and modified in a consistent and secure way.
#
# Abstraction :
# Encapsulation helps achieve abstraction by  exposing only the essential features of an object and hiding the complex
# implementation details. This allows you to work with objects at a higher level of abstraction, without needing to know or care
# about the internal working of the object.

# %%
# Example : 
class BankAccount : 
    def __init__(self, owner, balance): 
        self.__owner = owner   # Private Attribute 
        self.__balance = balance  # Private Attribute  

    def deposit (self, amount): 
        self.__balance  += amount 

    def withdraw(self, amount): 
        if self.__balance >= amount :
            self.__balance -= amount 
        else :
            print("Insufficient funds")

    def get_balance(self): 
        return self._balance 
    
    def get_owner(self): 
        return self.__owner

# %% [markdown]
# in this bank_account encapsulates, the account owner and balance as private attributes and provides controlled access to these attributes through public methods (deposit(), withdraw(), get_balance(), and get_owner)
#
# This promotes data hiding and abstraction, enuring the internal implemantation details of the bank account class are hidden from the
# outside world.

# %% [markdown]
# Q12.  Explain the Getter and Setter method in Python with examples and exlain its importance.

# %% [markdown]
# Ans.
# Getter and Setters in Python :
# Getters and Setters are methods used to access and modify the values of private or protected attributes in a class.
#
# Getters :
# Getters are the methods that provide the read - only access to private or protected attributes of a class. They allow you to retriiive thevalue of an attribute without exposing the internal implementation details.

# %%
class Person :
    def __init__(self, name, age): 
        self.__name = name 
        self.__age = age 
    
    def get_name(self):
        return self.__name
    
    def get_age(self):
        return self.__age   
    
    def set_age(self, new_age): 
        if new_age < 0 :
            print("Age cannot be negative")

        else : 
            self.__age = new_age

# %% [markdown]
# The set__age() method is a setter that allows you to update the age attribute, with a check to ensure that new age is non negative.
#
# Getters and setters are important because they :
#
# Provide a way to control access the object attributes.
# Allow for data validation and normalization.
# Enable for the implmentation of computed properties.
# Facilitate the future modifications to the class without effecting the existing code.

# %% [markdown]
# Q13. Discuss the concept of inheritance and explain all the types of inheritance with suitable examples in Python.
#
# How are sub classes created and what advantages does inheritance offer ?

# %% [markdown]
# Ans.
# Inheritance in Python :
# Inheritance in Python is  a fundamental concept in object oriented programming, that allows you to create the new classes
# based on the existing classes.
#
# The new classes inherit the attributes and methods of exsiting classes and can also add and modify them.
#
# Types on inheritance in Python :

# %% [markdown]
# 1. Single Inheritance :  A derived class inherits from the base class.

# %%
class  Animal : 
    def __init__(self,name): 
        self.name = name 

    def speak(self): 
        print("The animal makes a sound") 

class Dog(Animal):
    def  __init__(self,name): 
        super().__init__(name)

        def speak(self): 
            print("The dog barks")

# %% [markdown]
# Multiple Inheritance : A multiple inheritance inherits from multiple base cases

# %%
class Flyer : 
    def fly(self): 
        print("The animal is flying") 

class Swimmer:
    def swim(self):
        print("The animal is swimming")

class Duck(Flyer, Swimmer): 
    def __init__(self,name): 
        self.name = name

# %% [markdown]
# Multilevel Inheritance : A derived class inherits from another derived class.

# %%
class GrandParent :  
    def __init__(self,name): 
        self.name = name 

class Parent(GrandParent): 
        def introduce(self):
            print(f'Hello my naem is {self.name}')

class Child(Parent) : 
     def baby_talk(self): 
          print("Go goo ga ga!")

# %% [markdown]
# Hierarchial Inheritance :
# Multiple derived cases inherit from single base class.

# %%
class Animal : 
    def __init__(self,name): 
        self.name = name 

class Dog(Animal): 
        def speak(self): 
            print("The dog barks") 

class cat(Animal): 
        def speak(self):
            print("The cat meows")

# %% [markdown]
# Hybrid Inheritance : It is a combintion of multiple inheritance and single inheritance, it occurs when a class
#                      inherits from one or more than one base class, and at leastone of the base cases  isitself a derived class.

# %%
class GrandParent : 
    def grandparent_method(self): 
        print(" This is Grand Parent class")

class Parent1(GrandParent):
    def parent1_method(self):
        print("This is the Parent1 Class") 

class Parent2(GrandParent):
    def parent2_method(self):
        print("This is called Parent2 Class") 

class Child(Parent1, Parent2): 
    def child_method(self):
        print("this is the child class")
# Create an Instance of Chlld Class 

child_obj = Child()  

child_obj.child_method() 
child_obj.parent1_method()
child_obj.parent2_method()
child_obj.grandparent_method()

# In the example, the Child Class inherits from both the Parent1 and Pareent2  hich are themselves derived from the Grand Parnet Class
# Out:
# this is the child class
# This is the Parent1 Class
# This is called Parent2 Class
#  This is Grand Parent class

# %% [markdown]
# Advantages of Inheritance :
#
# Code Reuse : Inherited Classes can reuse the code from the base class, reducing the code duplication.
#
# Polymorphism :  Subclasses can over ride or extend the behaviour of the base class.
#
# Flexibility : Inheritance allows the creation of hierarchy of related classes, making the code more flexible and
#               maintainable.

# %% [markdown]
# Q14. Explain the concept of method overriding in python classes. How does it allow sub classes to modify the behaviour of
#         superclass  methods ?

# %% [markdown]
# Ans.
# Method Overiding in Python  :
# Method overriding is a feature in object oriented programming that allows a sub class to provide its own implementation of
#  a method that is already defined.
#
# This allows the sub classesto modify the behaviour of super classs method to suit their specific needs.

# %%
class Animal : 
    def make_sound(self):
        print("The animal makes a sound") 

class Dog(Animal): 
    def make_sound(self): 
        print("The dog barks") 

dog = Dog()
dog.make_sound()

animal = Animal()
animal.make_sound()
# Out:
# The dog barks
# The animal makes a sound

# %% [markdown]
# In this example,  Dog class overrides the make_sound() method inherited from the "Animal" class.
#
# When the make_sound() method is called on the instance of the Dog class, it executes the implementation in the
# Dog class rather than, implementation in Animal Class.
#
# Method overriding allows sub classes to provide their own specialized  implementation of a method, while still maintaining
# the same method signature as super class.
#
# This is a key aspect of polymorphism, as it allows the objects of different classess to be treated  as objects of a common class.

# %% [markdown]
# Q15. Discuss the signifiance of super() function in Python inheritance. How is it used and what role does it play in accessing the super classmethods and attributes ?

# %% [markdown]
# super() Function in Python inheritance :
# The super function in Python is used to call a method in a super class from a  sub classs.
#
# It provides a way to access and invokemethods defined in the base of a class.

# %%
class Animal : 
    def __init__(self,name):
        self.name = name 

    def speak(self): 
        print("The animal males a sound")  

    class Dog(Animal): 
        def __init__(self, name,breed): 
            super().__init__(name)
            self.breed = breed

        def speak(self): 
            super().speak()
            print("The Dog barks")

# %% [markdown]
# In this example, __init__ method of the dog class, __init__ name calls the method of the "Animal"Class allowing the dog
# class to inherit the class to inherit the name attribute.
#
# In the speak,  method class super().speak() class the speak() method of Animal Class.
#
# The super() function plays a crucial role in accessing and invoking the methods and attributes from the superclass.
#
# When working from the inheritanceheirarchies, it helps to maintain the linkage between subclass and super class.
#
# It makes the code more modular, maintainable and flexible.

# %% [markdown]
# Q16. Explain the Method Resolution Order in detail with example. Explin with example its importance.

# %% [markdown]
# Method Resolution Order(MRo) in Python :
#
# Method Resolution Order (MRO) is the order in which Python searches for the method in the inheritance hierarchy.
#
# When a method is called on an object, Python follows the MRO to find the appropriate implementation method.

# %%
class  A : 
    pass 

class B : 
    pass 

class C(A): 
    pass

class D(B,C): 
    pass

print(D.__mro__)
# Out:
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)

# %% [markdown]
# MRO is important because it determines which method implementation will be used when a method implementation will be used.
#
# Python follows a specific program to determine the MRO, known as C3 Linearixation algorithm.
#
# Understanding the MRo  is crucial, when working with multiple inheritance, as it helps to predict the behaviour
# of your codeand avoid the potentialconnflicts or unexpected results.
#
# The MRo is useful when working with the super() functuiion, as it ensures the correct super class method is called, even in
# complex inheritance hierarchies.
#
# In hierarchy,  MRO is a fundamntal concept in Python's object oriented programming model and understanding, it is essential for
# writingrobust and maintainable code.
