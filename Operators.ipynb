# %%
# Arithmetic operators 

num1 = 10
num2 = 20
print(num1 + num2)
# Addition
# Out:
# 30

# %%
print(num2 - num1)
# Subtraction
# Out:
# 10

# %%
# Multiplication 
print(num1*num2)
# Out:
# 200

# %%
# Division in 2 different numerators and denominators 
print(num2/num1)
print(num1/num2)
# Out:
# 2.0
# 0.5

# %%
# Example of Division 
print(23/3) # Gives the floating value 
print(23//3) # Gives the quotient value 
print(23%3) # Gives the remainder value
# Out:
# 7.666666666666667
# 7
# 2

# %%
num = int(input("Enter the number"))
print(num % 2 == 0) # On entering the number we print the output and hence we get the result 
# Number entered = 51
# Out:
# False

# %%
num = int(input("Enter the number"))
print(num % 2 == 0) # On entering the number we print the output and hence we get the result 
# Number entered = 42
# Out:
# True

# %%
# Exponenet Operator 
print(2**3)
# it is basically 2 to power 3
# Out:
# 8

# %%
n = int(input("Enter the number"))
print(n**3)
# Number entered is 3
# Out:
# 27

# %%
pos_inf = float("inf")
print(pos_inf)
# Storing the positive integer
# Out:
# inf

# %%
neg_inf = float("-inf")
print(neg_inf)
# Storing the negative integer
# Out:
# -inf

# %%
   # Comparison Operators 
num1 = 10
num2 = 20 
print(num1 == num2)
# == sign is used for making the comparison so it prints False
# Out:
# False

# %%
print(num1 != num2)
#  Since num1 is not equal to num2 so it prints True
# Out:
# True

# %%
print(num1 < num2)
# Since the number 1 is less than numner 2 so it prints true
# Out:
# True

# %%
print(num1 > num2)
# Since the number 1 is ;ess than numner2  so it prints false
# Out:
# False

# %%
print(pos_inf > neg_inf)
# it prints True
# Out:
# True

# %%
x = float('nan')
y = 5
z = float('nan')

print(x ==y)
print(y == z)
# both are false as because the y and z both have nan values but still are unequal
# Out:
# False
# False

# %%
# Assignment operators 
name = "Vishwa"
x = 5 
x = x+5 
print(x)
# Here = is use as an assignment operator so hence 5 is assigned to the x and so it prints 10
# Out:
# 10

# %%
x+=5
print(x)
# Since the previous stored value was 10,, so on adding 5 it prints 15
# Out:
# 15

# %%
x-=3
print(x)
# here 3 gets subtracted from 15
# Out:
# 12

# %%
x*= 2
print(x)
# Since the pre defined value of x is 12, so on multiplying 2 it prints 24
# Out:
# 24

# %%
# logical Operators 
# And Operator 
print(True and False)
# Out:
# False

# %%
print(True and True)
# Out:
# True

# %%
print(False and False)
# Out:
# False

# %%
# OR operator 
print(True or False )
# Out:
# True

# %%
print(True and False)
print(False and True)
print(False and False)
print(False or False)
# Out:
# False
# False
# False
# False

# %%
print(not True)
# not true means False 
# This is a boolean Expression
# Out:
# False

# %%
print(not False) 
# Here this is a boolean expression
# Out:
# True

# %%
print(not 5>7)
# Since 5 is less than 7 and when we put not so it beccome True
# Out:
# True

# %%
# XOR operator represented by ^
print(True ^ False )
# Out:
# True

# %%
print(True ^True)
print( False ^False)
# Out:
# False
# False

# %%
# Bitwise And Operator &
num1 = 5
num2 = 3 
print(num1 & num2)
# Here basically we calcu;ate Bitwise 
# So what happens is that we have to convert the number into bits and then we carry out the comparison and hence we give the answer 1
# Out:
# 1

# %%
# Bitwise OR Operator 
num1 = 5
num2 = 3 
print(num1 | num2)
# Out:
# 7

# %%
# Examples by som Maths Problems 
print( 1 - 4*0.25)
# We get the answer
# Out:
# 0.0

# %%
print(0.9-3*0.3)
# Here why the value is not zero
# Out:
# 1.1102230246251565e-16

# %%
# Unary Operator left Shift
num = 5
print(num << 1)
# Out:
# 10

# %%
# Unary Operator Left Shift
num = 14
print(num << 1)
# Out:
# 28

# %%
# unary Operator Right Shift 
num = 14
print (num >> 1)
# Out:
# 7

# %%
# Identity Operator 
x = 5
y = 5
print(x is y)
# hence x is equual to y
# Out:
# True

# %%
arr1 =[1,2,3]
arr2 = [1,2,3]
print(arr1 is arr2)
print(arr1 is not arr2)

# Although the content of array is same, but still its considered different as 2 different objects stored in 2 different memory locations
# Out:
# False
# True

# %%
# Membership Operator 
my_list =  [1,2,3,4,5]
print(5 in my_list)
print(7 in my_list)
# Out:
# True
# False

# %%
# operator Precedence 
result = 4 + 5*6
print(result)
# Out:
# 34
