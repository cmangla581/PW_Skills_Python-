# %%
# Implicit Typecasting 
x = 5 
y = 6.5
result = x + y
print(x + y)
# Out:
# 11.5

# %%
y ='10'
print(type(y))
int_y = int(y)
print(type(int_y))
# first one is string and the second one is integer
# Out:
# <class 'str'>
# <class 'int'>

# %%
data = 'one'
print(int(data))
# error comes due to incompaible data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 data = 'one'
# ----> 2 print(int(data))
#
# ValueError: invalid literal for int() with base 10: 'one'
